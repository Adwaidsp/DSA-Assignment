# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset

df = pd.read_csv(r'C:\Users\USER\Downloads\airline_passenger_satisfaction.csv')

# %%
# Display first 5 rows of dataset

df.head()
# Out:
#    Unnamed: 0  Gender      customer_type  age   type_of_travel customer_class  \
# 0           0    Male     Loyal Customer   13  Personal Travel       Eco Plus
# 1           1    Male  disloyal Customer   25  Business travel       Business
# 2           2  Female     Loyal Customer   26  Business travel       Business
# 3           3  Female     Loyal Customer   25  Business travel       Business
# 4           4    Male     Loyal Customer   61  Business travel       Business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
# ...

# %%
# shape of dataset

print(df.shape)
# Out:
# (129880, 24)

# %%
# columns in dataset

df.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'customer_type', 'age', 'type_of_travel',
#        'customer_class', 'flight_distance', 'inflight_wifi_service',
#        'departure_arrival_time_convenient', 'ease_of_online_booking',
#        'gate_location', 'food_and_drink', 'online_boarding', 'seat_comfort',
#        'inflight_entertainment', 'onboard_service', 'leg_room_service',
#        'baggage_handling', 'checkin_service', 'inflight_service',
#        'cleanliness', 'departure_delay_in_minutes', 'arrival_delay_in_minutes',
#        'satisfaction'],
#       dtype='object')

# %%
# Information about dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         129880 non-null  int64
#  1   Gender                             129880 non-null  object
#  2   customer_type                      129880 non-null  object
#  3   age                                129880 non-null  int64
#  4   type_of_travel                     129880 non-null  object
#  5   customer_class                     129880 non-null  object
#  6   flight_distance                    129880 non-null  int64
#  7   inflight_wifi_service              129880 non-null  int64
#  8   departure_arrival_time_convenient  129880 non-null  int64
#  9   ease_of_online_booking             129880 non-null  int64
#  10  gate_location                      129880 non-null  int64
# ...

# %%
# Statistical summary of dataset

df.describe()
# Out:
#           Unnamed: 0            age  flight_distance  inflight_wifi_service  \
# count  129880.000000  129880.000000    129880.000000          129880.000000
# mean    64939.500000      39.427957      1190.316392               2.728696
# std     37493.270818      15.119360       997.452477               1.329340
# min         0.000000       7.000000        31.000000               0.000000
# 25%     32469.750000      27.000000       414.000000               2.000000
# 50%     64939.500000      40.000000       844.000000               3.000000
# 75%     97409.250000      51.000000      1744.000000               4.000000
# max    129879.000000      85.000000      4983.000000               5.000000
#
#        departure_arrival_time_convenient  ease_of_online_booking  \
# count                      129880.000000           129880.000000
# mean                            3.057599                2.756876
# std                             1.526741                1.401740
# ...

# %%
# Datatypes in dataset

df.dtypes
# Out:
# Unnamed: 0                             int64
# Gender                                object
# customer_type                         object
# age                                    int64
# type_of_travel                        object
# customer_class                        object
# flight_distance                        int64
# inflight_wifi_service                  int64
# departure_arrival_time_convenient      int64
# ease_of_online_booking                 int64
# gate_location                          int64
# food_and_drink                         int64
# online_boarding                        int64
# seat_comfort                           int64
# inflight_entertainment                 int64
# onboard_service                        int64
# leg_room_service                       int64
# baggage_handling                       int64
# checkin_service                        int64
# inflight_service                       int64
# cleanliness                            int64
# ...

# %%
# check for missing values in dataset

df.isnull().sum()
# Out:
# Unnamed: 0                             0
# Gender                                 0
# customer_type                          0
# age                                    0
# type_of_travel                         0
# customer_class                         0
# flight_distance                        0
# inflight_wifi_service                  0
# departure_arrival_time_convenient      0
# ease_of_online_booking                 0
# gate_location                          0
# food_and_drink                         0
# online_boarding                        0
# seat_comfort                           0
# inflight_entertainment                 0
# onboard_service                        0
# leg_room_service                       0
# baggage_handling                       0
# checkin_service                        0
# inflight_service                       0
# cleanliness                            0
# departure_delay_in_minutes             0
# arrival_delay_in_minutes             393
# ...

# %%
# Filling missing values in arrival_delay_in_minutes column

df['arrival_delay_in_minutes'].fillna(df['arrival_delay_in_minutes'].mean(),inplace = True)

# %%
# check for duplicates in dataset

df.duplicated().sum()
# Out:
# 0

# %%
# Drop unnecessary column

df.drop('Unnamed: 0',axis=1)
# Out:
#         Gender      customer_type  age   type_of_travel customer_class  \
# 0         Male     Loyal Customer   13  Personal Travel       Eco Plus
# 1         Male  disloyal Customer   25  Business travel       Business
# 2       Female     Loyal Customer   26  Business travel       Business
# 3       Female     Loyal Customer   25  Business travel       Business
# 4         Male     Loyal Customer   61  Business travel       Business
# ...        ...                ...  ...              ...            ...
# 129875    Male  disloyal Customer   34  Business travel       Business
# 129876    Male     Loyal Customer   23  Business travel       Business
# 129877  Female     Loyal Customer   17  Personal Travel            Eco
# 129878    Male     Loyal Customer   14  Business travel       Business
# 129879  Female     Loyal Customer   42  Personal Travel            Eco
#
#         flight_distance  inflight_wifi_service  \
# 0                   460                      3
# ...

# %%
# Checking nature of dataset with target column satisfaction

df['satisfaction'].value_counts(normalize=True).plot.bar(color=['blue','green'])
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# The above plot shows 55% neutral or dissatisfied and 45% satisfied.So the data is quite balanced

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Univariate Analysis :

# %% [markdown]
# Categorical variables : Gender, customer_type, type_of_travel, customer_class, inflight_wifi_service, departure_arrival_time_convenient, ease_of_online_booking, gate_location, food_and_drink, online_boarding,                     seat_comfort, inflight_entertainment, onboard_service, leg_room_service, baggage_handling, checkin_service,                      inflight_service, cleanliness, satisfaction.
#
#
# Numerical columns: age, flight_distance, departure_delay_in_minutes, arrival_delay_in_minutes.

# %%
# customer_type present in dataset

df['customer_type'].unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer'], dtype=object)

# %%
# type_of_travel present in dataset

df['type_of_travel'].unique()
# Out:
# array(['Personal Travel', 'Business travel'], dtype=object)

# %%
# customer_class present in dataset

df['customer_class'].unique()
# Out:
# array(['Eco Plus', 'Business', 'Eco'], dtype=object)

# %%
# satisfaction result present in dataset

df['satisfaction'].unique()
# Out:
# array(['neutral or dissatisfied', 'satisfied'], dtype=object)

# %%
# Percentage of gender

df['Gender'].value_counts(normalize=True)
# Out:
# Female    0.507384
# Male      0.492616
# Name: Gender, dtype: float64

# %%
# Percentage of customer_type

df['customer_type'].value_counts(normalize=True)
# Out:
# Loyal Customer       0.816908
# disloyal Customer    0.183092
# Name: customer_type, dtype: float64

# %%
# Percentage of type_of_travel

df['type_of_travel'].value_counts(normalize=True)
# Out:
# Business travel    0.690584
# Personal Travel    0.309416
# Name: type_of_travel, dtype: float64

# %%
# Percentage of customer_class

df['customer_class'].value_counts(normalize=True)
# Out:
# Business    0.478596
# Eco         0.448945
# Eco Plus    0.072459
# Name: customer_class, dtype: float64

# %%
# Percentage of satisfaction

df['satisfaction'].value_counts(normalize=True)
# Out:
# neutral or dissatisfied    0.565537
# satisfied                  0.434463
# Name: satisfaction, dtype: float64

# %%
# mean age

df['age'].mean()
# Out:
# 39.42795657530028

# %%
# Bar plot function

def bar_plot(variable):
    
    var=df[variable]
    var_Value=var.value_counts()
    
    #visualize
    plt.figure(figsize=(9,3))
    plt.bar(var_Value.index,var_Value.values)
    
    plt.xlabel("Passengers Score")
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,var_Value))

# %%
category_1 = ['inflight_wifi_service', 'departure_arrival_time_convenient', 'ease_of_online_booking', 'gate_location', 
              'food_and_drink', 'online_boarding', 'seat_comfort', 'inflight_entertainment', 'onboard_service', 
              'leg_room_service', 'baggage_handling', 'checkin_service', 'inflight_service', 'cleanliness']

for a in category_1:
    bar_plot(a)
# Out:
# inflight_wifi_service:
#  2    32320
# 3    32185
# 4    24775
# 1    22328
# 5    14356
# 0     3916
# Name: inflight_wifi_service, dtype: int64
# departure_arrival_time_convenient:
#  4    31880
# 5    27998
# 3    22378
# 2    21534
# 1    19409
# 0     6681
# Name: departure_arrival_time_convenient, dtype: int64
# ease_of_online_booking:
#  3    30393
# 2    30051
# 4    24444
# 1    21886
# 5    17424
# 0     5682
# Name: ease_of_online_booking, dtype: int64
# gate_location:
#  3    35717
# 4    30466
# 2    24296
# 1    21991
# 5    17409
# 0        1
# Name: gate_location, dtype: int64
# food_and_drink:
#  4    30563
# 5    27957
# 3    27794
# 2    27383
# 1    16051
# 0      132
# Name: food_and_drink, dtype: int64
# online_boarding:
#  4    38468
# 3    27117
# 5    26020
# 2    21934
# 1    13261
# 0     3080
# Name: online_boarding, dtype: int64
# seat_comfort:
#  4    39756
# 5    33158
# 3    23328
# 2    18529
# 1    15108
# 0        1
# ...

# %%
category_2 = ['Gender', 'customer_type', 'type_of_travel', 'customer_class','satisfaction']

for a in category_2:
    print("{} \n".format(df[a].value_counts()))
# Out:
# Female    65899
# Male      63981
# Name: Gender, dtype: int64
#
# Loyal Customer       106100
# disloyal Customer     23780
# Name: customer_type, dtype: int64
#
# Business travel    89693
# Personal Travel    40187
# Name: type_of_travel, dtype: int64
#
# Business    62160
# Eco         58309
# Eco Plus     9411
# Name: customer_class, dtype: int64
#
# neutral or dissatisfied    73452
# satisfied                  56428
# Name: satisfaction, dtype: int64

# %%
# Histogram plot function

def plot_hist(variable):
    plt.figure(figsize=(9,3))
    plt.hist(df[variable],bins=50)
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title("{} distribution with histogram".format(variable))
    plt.show()

# %%
numerical_var = ['age','flight_distance', 'departure_delay_in_minutes', 'arrival_delay_in_minutes']

for n in numerical_var:
    plot_hist(n)

# %% [markdown]
# # Bivariate Analysis

# %%
# Gender vs satisfaction

sns.countplot(x='Gender', hue='satisfaction',data=df)
plt.show()

# %%
# customer_type vs satisfaction

sns.countplot(x='customer_type', hue='satisfaction',data=df)
plt.show()

# %%
# customer_class vs satisfaction

sns.countplot(x='customer_class', hue='satisfaction',data=df)
plt.show()

# %%
# type_of_travel vs satisfaction

sns.countplot(x='type_of_travel', hue='satisfaction',data=df)
plt.show()

# %%
# ease_of_online_booking vs satisfaction

sns.countplot(x='ease_of_online_booking', hue='satisfaction',data=df)
plt.show()

# %%
# seat_comfort vs satisfaction

sns.countplot(x='seat_comfort', hue='satisfaction',data=df)
plt.show()

# %%
# cleanliness vs satisfaction

sns.countplot(x='cleanliness', hue='satisfaction',data=df)
plt.show()

# %%
# food_and_drink vs satisfaction

sns.countplot(x='food_and_drink', hue='satisfaction',data=df)
plt.show()

# %%
# onboard_service vs satisfaction

sns.countplot(x='onboard_service', hue='satisfaction',data=df)
plt.show()

# %%
# leg_room_service vs satisfaction

sns.countplot(x='leg_room_service', hue='satisfaction',data=df)
plt.show()

# %%
# checkin_service vs satisfaction

sns.countplot(x='checkin_service', hue='satisfaction',data=df)
plt.show()

# %%
# inflight_service vs satisfaction

sns.countplot(x='inflight_service', hue='satisfaction',data=df)
plt.show()

# %%
# baggage_handling vs satisfaction

sns.countplot(x='baggage_handling', hue='satisfaction',data=df)
plt.show()

# %%
# Which customer_class had travelled a long flight_distance?

df.groupby(['customer_class'])['flight_distance'].mean()
# Out:
# customer_class
# Business    1676.088256
# Eco          743.998199
# Eco Plus     747.089151
# Name: flight_distance, dtype: float64

# %% [markdown]
# Business class had travelled long flight distance

# %%
# Which customer_class had travelled a long flight_distance? (Bar plot )

df.groupby(['customer_class'])['flight_distance'].mean().plot.bar(color='green')
plt.xticks(rotation=0)
plt.xlabel('customer_class')
plt.ylabel('flight_distance')
plt.title('customer_class vs flight_distance')
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
# customer_class vs flight_distance in relation with satisfaction

sns.catplot(x='customer_class',y='flight_distance', hue='satisfaction',data=df,kind='bar')
plt.show()

# %%
# type_of_travel vs flight_distance in relation with satisfaction

sns.catplot(x='type_of_travel',y='flight_distance', hue='satisfaction',data=df,kind='bar')
plt.show()

# %%
# Gender vs flight_distance in relation with satisfaction

sns.catplot(x='Gender',y='flight_distance', hue='satisfaction',data=df,kind='bar')
plt.show()

# %%
# departure_arrival_time_convenient vs online_boarding in relation with satisfaction

sns.catplot(x="departure_arrival_time_convenient",y="online_boarding",hue="satisfaction",col="customer_class",
            data=df,kind="bar")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# customer_class vs departure_delay_in_minutes in relation with satisfaction

sns.catplot(x="customer_class",y="departure_delay_in_minutes",hue="satisfaction",col="type_of_travel",
            data=df, kind="bar")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# customer_class vs arrival_delay_in_minutes in relation with satisfaction

sns.catplot(x="customer_class",y="arrival_delay_in_minutes",hue="satisfaction",col="type_of_travel",
            data=df, kind="bar")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
